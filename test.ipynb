# %%
for a in {1:'1',2:'2',3:'4'}.values():
    print(a)
# Out:
# 1
# 2
# 4

# %%
(1, 2, 3) + (3, ), (1, 2, 3)[0]
# Out:
# ((1, 2, 3, 3), 1)

# %%
str((1,2,3)).strip('()')
# Out:
# '1, 2, 3'

# %%
exec("a=1")

# %%
s='add'

# %%
eval(f"{s}={a}")
# Out:
# Traceback (most recent call last):
#
#   File d:\Pythons\basic\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3667 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[30], line 1
#     eval(f"{s}={a}")
#
#   File <string>:1
#     add=1
#        ^
# SyntaxError: invalid syntax

# %%
class Arr:
    def __init__(self) -> None:
        exec("self.a = []")

# %%
a = Arr()

# %%
eval("a.a")
# Out:
# []

# %%
sum([])
# Out:
# 0

# %%
# tmp = ()
tmp += (0,)

# %%
tmp
# Out:
# (0, 0)

# %%
sum([])
# Out:
# 0

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %%
ad = {'2':1, '1':2}

# %%
'a'.isdigit()
# Out:
# False

# %%
sorted(ad.items(), key=),ad
# Out:
# (['1', '2'], {'2': 1, '1': 2})
